# %% [markdown]
#  # Docker tutorial

# %%
import os

# %% [markdown]
# Following this tutorial:
#
# https://docs.docker.com/get-started/
#
# ## Terminology
# * Container: the running process. A running instance of an image
# * Image: Provides the filesystem. Contains all dependencies, configurations.

# %%
# Get the getting-started-app repo
# !git clone https://github.com/docker/getting-started-app.git
# Out:
# Cloning into 'getting-started-app'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 68 (delta 12), reused 10 (delta 10), pack-reused 33
# Receiving objects: 100% (68/68), 1.75 MiB | 3.54 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
os.chdir('getting-started-app')

# %%
# Build the image
# !docker build -t getting-started .
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 218B                                       0.0s
#  => resolve image config for docker.io/docker/dockerfile:1                 0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 218B                                       0.0s
#  => resolve image config for docker.io/docker/dockerfile:1                 0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
# ...

# %%
# Start the Docker container
# !docker run -dp 127.0.0.1:3000:3000 getting-started
# Out:
# 3f3a6664f81b3fad7fff330a5b4d852a17c95b93571505f4d212a2b727036559

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE             COMMAND                  CREATED          STATUS          PORTS                      NAMES
# 3f3a6664f81b   getting-started   "docker-entrypoint.s…"   53 seconds ago   Up 52 seconds   127.0.0.1:3000->3000/tcp   kind_perlman

# %%
# !docker container stop laughing_kalam
# Out:
# laughing_kalam
